# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
import numpy as np
import xlrd
import xlwt
import openpyxl

# %%
qarot_data = pd.read_csv('QAROT_data_use.csv') #sanctionstrenght. placementstrength categorical
qarot_managed = pd.read_excel('QAROT_data_managed.xlsx')

# %%
qarot_country = qarot_managed[['country']]
qarot_country
# Out:
#                          country
# 0                    Afghanistan
# 1                        Albania
# 2                        Algeria
# 3                        Andorra
# 4                         Angola
# 5            Antigua and Barbuda
# 6                     Azerbaijan
# 7                      Argentina
# 8                      Australia
# 9                        Austria
# 10                       Bahamas
# 11                       Bahrain
# 12                    Bangladesh
# 13                       Armenia
# 14                      Barbados
# 15                       Belgium
# 16                        Bhutan
# 17                       Bolivia
# 18        Bosnia and Herzegovina
# 19                      Botswana
# 20                        Brazil
# 21                        Belize
# 22               Solomon Islands
# 23                        Brunei
# 24                      Bulgaria
# 25                       Myanmar
# 26                       Burundi
# ...

# %%
qarot_data = qarot_data[qarot_data.columns.drop(list(qarot_data.filter(regex='Unnamed')))]

# %%
qarot_data.columns
#qarot_managed.country
# Out:
# Index(['country', 'year', 'code', 'code.year', 'adopted.quota',
#        'implemented.quota', 'first.adopt.flag', 'first.implement.flag',
#        'adopted.reform.flag', 'implemented.reform.flag', 'quota.reform.number',
#        'implement.reform.number', 'type', 'percent.stated.threshold',
#        'percent.of.seats', 'defacto.threshold', 'sanctions',
#        'sanctions.strength', 'placement', 'placement.strength',
#        'reserved.separate.tier', 'reserved.best.loser', 'reserved.indirect',
#        'reserved.unspecified', 'effective.quota', 'women.rep'],
#       dtype='object')

# %%
qarot_data['adopted.reform.flag'] = qarot_data['adopted.reform.flag'].fillna(0)
qarot_data['implemented.reform.flag'] = qarot_data['implemented.reform.flag'].fillna(0)
qarot_data['quota.reform.number'] = qarot_data['quota.reform.number'].fillna(0)
qarot_data['implement.reform.number'] = qarot_data['implement.reform.number'].fillna(0)
qarot_data['percent.stated.threshold'] = qarot_data['percent.stated.threshold'].fillna(0)
qarot_data['percent.of.seats'] = qarot_data['percent.of.seats'].fillna(0)
qarot_data['defacto.threshold'] = qarot_data['defacto.threshold'].fillna(0)
qarot_data['sanctions'] = qarot_data['sanctions'].fillna(0)
qarot_data['placement'] = qarot_data['placement'].fillna(0)
qarot_data['reserved.separate.tier'] = qarot_data['reserved.separate.tier'].fillna(0)
qarot_data['reserved.best.loser'] = qarot_data['reserved.best.loser'].fillna(0)
qarot_data['reserved.indirect'] = qarot_data['reserved.indirect'].fillna(0)
qarot_data['reserved.unspecified'] = qarot_data['reserved.unspecified'].fillna(0)
qarot_data['effective.quota'] = qarot_data['effective.quota'].fillna(0)
qarot_data['women.rep'] = qarot_data['women.rep'].fillna(0)

# %%
qarot_data['sanctions'].unique()
# Out:
# array([0., 1.])

# %%
df = qarot_data.groupby(['country'], as_index = False).mean()
df
# Out:
#                     country    year  adopted.quota  implemented.quota  \
# 0               Afghanistan  1981.0       0.173913           0.159420
# 1                   Albania  1981.0       0.115942           0.101449
# 2                   Algeria  1988.5       0.074074           0.074074
# 3                   Andorra  1981.0       0.000000           0.000000
# 4                    Angola  1981.0       0.159420           0.115942
# 5       Antigua and Barbuda  1998.0       0.000000           0.000000
# 6                 Argentina  1981.0       0.362319           0.333333
# 7                   Armenia  1981.0       0.246377           0.188406
# 8                 Australia  1981.0       0.000000           0.000000
# 9                   Austria  1981.0       0.000000           0.000000
# 10               Azerbaijan  2003.0       0.000000           0.000000
# 11                  Bahrain  1993.0       0.000000           0.000000
# ...

# %%
qarot_country_year = qarot_data[['country', 'year']]
df3 = qarot_country_year.groupby(['country'], as_index = False).count()
df3
# Out:
#                     country  year
# 0               Afghanistan    69
# 1                   Albania    69
# 2                   Algeria    54
# 3                   Andorra    69
# 4                    Angola    69
# 5       Antigua and Barbuda    35
# 6                 Argentina    69
# 7                   Armenia    69
# 8                 Australia    69
# 9                   Austria    69
# 10               Azerbaijan    25
# 11                  Bahrain    45
# 12               Bangladesh    45
# 13                  Belarus    26
# 14                  Belgium    69
# 15                   Belize    69
# 16                    Benin    56
# 17                   Bhutan    69
# 18                  Bolivia    69
# 19   Bosnia and Herzegovina    24
# 20                 Botswana    50
# 21                   Brazil    69
# 22        Brunei Darussalam    32
# 23                 Bulgaria    69
# 24             Burkina Faso    56
# 25                  Burundi    54
# ...

# %%
df2 = qarot_country.merge(df3, on = ['country'], how = 'left')

# %%
df2
# Out:
#                          country  year
# 0                    Afghanistan  69.0
# 1                        Albania  69.0
# 2                        Algeria  54.0
# 3                        Andorra  69.0
# 4                         Angola  69.0
# 5            Antigua and Barbuda  35.0
# 6                     Azerbaijan  25.0
# 7                      Argentina  69.0
# 8                      Australia  69.0
# 9                        Austria  69.0
# 10                       Bahamas   NaN
# 11                       Bahrain  45.0
# 12                    Bangladesh  45.0
# 13                       Armenia  69.0
# 14                      Barbados   NaN
# 15                       Belgium  69.0
# 16                        Bhutan  69.0
# 17                       Bolivia  69.0
# 18        Bosnia and Herzegovina  24.0
# 19                      Botswana  50.0
# 20                        Brazil  69.0
# 21                        Belize  69.0
# 22               Solomon Islands  38.0
# ...

# %%
df3[['year']].to_clipboard()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-3aef60fdd39c> in <module>()
# ----> 1 a = df[['type']]
#       2 a
#
# c:\users\toshiba\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# c:\users\toshiba\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
df2[['year']].to_clipboard(index=None)

# %%
df2.to_excel('results.xlsx', sheet_name='sheet1', index=False)
